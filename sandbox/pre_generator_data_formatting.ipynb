# %%
import numpy as np
import mat73
from scipy.io import loadmat
import os
import h5py
import re

# %%
room_list = ["bomb_shelter",
             "gym",
             "pb132",
             "pc226",
             "sa203",
             "sc203",
             "se203",
             "tb103",
             "tc352"]

tau_srir_path = '/scratch/ci411/TAU_SRIR_DB/TAU-SRIR_DB'

measinfomat = loadmat(tau_srir_path + '/measinfo.mat')['measinfo']

rirdatamat = loadmat(tau_srir_path + '/rirdata.mat')
rirdata = rirdatamat['rirdata']['room'][0][0]

# %%
for ri in range(9):
    n_t = len(rirdata[ri][0][2])
    print(room_list[ri])
    for ti in range(n_t):
        n_h = len(rirdata[ri][0][2][ti])
        for hi in range(n_h):
            print(rirdata[ri][0][2][ti][hi][0].shape)
# Out:
# bomb_shelter
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# gym
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# pb132
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# pc226
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# sa203
# (72, 3)
# (70, 3)
# (67, 3)
# (86, 3)
# (83, 3)
# (80, 3)
# (108, 3)
# (104, 3)
# (99, 3)
# (111, 3)
# (113, 3)
# (113, 3)
# (88, 3)
# (90, 3)
# (91, 3)
# (72, 3)
# (73, 3)
# (74, 3)
# sc203
# (61, 3)
# (61, 3)
# (61, 3)
# (61, 3)
# (61, 3)
# (97, 3)
# (99, 3)
# (99, 3)
# (99, 3)
# (97, 3)
# (97, 3)
# (99, 3)
# (99, 3)
# (99, 3)
# (97, 3)
# (61, 3)
# (61, 3)
# (61, 3)
# (61, 3)
# (61, 3)
# se203
# (93, 3)
# (93, 3)
# (93, 3)
# (92, 3)
# (128, 3)
# (128, 3)
# (127, 3)
# (126, 3)
# (128, 3)
# (128, 3)
# (127, 3)
# (126, 3)
# (93, 3)
# (93, 3)
# (93, 3)
# (92, 3)
# tb103
# (84, 3)
# (82, 3)
# (81, 3)
# (121, 3)
# (118, 3)
# (114, 3)
# (117, 3)
# (118, 3)
# (118, 3)
# (76, 3)
# (77, 3)
# (78, 3)
# tc352
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)
# (360, 3)

# %%
measinfo = {}
# define a room number
for room_num in range(9):
    # get room name
    room_name = measinfomat['room'][room_num][0][0]
    measinfo[room_name] = {}

    # get room trajectories
    trajectories = [str(t[0]) for t in measinfomat['trajectories'][room_num][0][0]]
    measinfo[room_name]['trajectories'] = trajectories

    # get trajectory type
    trajectory_type = (measinfomat['trajectoryType'][room_num][0][0])
    measinfo[room_name]['trajectory_type'] = trajectory_type

    # get distances
    distances = np.array([t for t in measinfomat['distances'][room_num][0]])
    measinfo[room_name]['distances'] = distances

    # get heights
    heights = np.array([t for t in measinfomat['heights'][room_num][0]])
    measinfo[room_name]['heights'] = heights

    # get mic positions
    mic_position = np.array(measinfomat['micPosition'][room_num][0])
    measinfo[room_name]['mic_position'] = mic_position

# %%
measinfo['bomb_shelter']
# Out:
# {'trajectories': ['close', 'far'],
#  'trajectory_type': 'circular',
#  'distances': array([[2.5, 5. ]]),
#  'heights': array([[0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]]),
#  'mic_position': array([[0. , 0. , 1.2]])}
